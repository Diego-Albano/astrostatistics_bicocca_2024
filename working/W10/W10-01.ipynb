# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
day = []
day.append(1)       #0 clear, 1 cloudy

choice = [0, 1]     #clear/cloudy
for i in range(100000):
    if day[i] == 0:
        day.append(np.random.choice(choice, p=[0.9, 0.1]))
    if day[i] == 1:
        day.append(np.random.choice(choice, p=[0.5, 0.5]))

# %%
plt.plot(day)
